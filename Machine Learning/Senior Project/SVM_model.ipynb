# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df = pd.read_excel('data/z_Masterfile.xlsx').fillna(0)
features_considered = ["WTI_price", "WTI_open", "WTI_Change_PCT", "WTI_HL_PCT",
                       "Brent_Price", "Brent_Open", "Brent_change_PCT", "Brent_HL_PCT"]
features = df[features_considered]
features.index = df["Date"]
features.tail()


#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
# Out:
#             WTI_price  WTI_open  WTI_Change_PCT  WTI_HL_PCT  Brent_Price  \
# Date
# 2019-06-01      58.47     53.42          0.0929    0.159569        66.55
# 2019-07-01      58.58     59.27          0.0019    0.106180        65.17
# 2019-08-01      55.10     57.85         -0.0594    0.135572        60.43
# 2019-09-01      54.07     55.00         -0.0187    0.194932        60.78
# 2019-10-01      53.22     54.23         -0.0157    0.071965        58.66
#
#             Brent_Open  Brent_change_PCT  Brent_HL_PCT
# Date
# 2019-06-01       61.64            0.0319      0.111195
# 2019-07-01       65.05           -0.0207      0.097591
# 2019-08-01       64.09           -0.0727      0.143306
# 2019-09-01       58.80            0.0058      0.242185
# 2019-10-01       59.41           -0.0349      0.066996
