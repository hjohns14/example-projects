# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

wti_df = pd.read_csv('data/wti.csv')
brent_df = pd.read_csv('data/brent_crude.csv')
energy_etf_df = pd.read_csv('data/energy_sector_etf.csv')
opec_production_df = pd.read_csv('data/opec_production.csv')
truck_sales_df = pd.read_csv('data/truck_sales.csv')
us_prod_df = pd.read_csv('data/us_crude_production.csv')
dubai_df = pd.read_excel('data/dubai_crude.xlsx')


wti_df.set_index("Date")
pd.DatetimeIndex(wti_df.index)
# Out:
# DatetimeIndex([          '1970-01-01 00:00:00',
#                '1970-01-01 00:00:00.000000001',
#                '1970-01-01 00:00:00.000000002',
#                '1970-01-01 00:00:00.000000003',
#                '1970-01-01 00:00:00.000000004',
#                '1970-01-01 00:00:00.000000005',
#                '1970-01-01 00:00:00.000000006',
#                '1970-01-01 00:00:00.000000007',
#                '1970-01-01 00:00:00.000000008',
#                '1970-01-01 00:00:00.000000009',
#                ...
#                '1970-01-01 00:00:00.000000429',
#                '1970-01-01 00:00:00.000000430',
#                '1970-01-01 00:00:00.000000431',
#                '1970-01-01 00:00:00.000000432',
#                '1970-01-01 00:00:00.000000433',
#                '1970-01-01 00:00:00.000000434',
#                '1970-01-01 00:00:00.000000435',
#                '1970-01-01 00:00:00.000000436',
#                '1970-01-01 00:00:00.000000437',
# ...

# %%
plt.figure()
'''plt.subplot(221)
plt.plot(wti_df['Date'], wti_df['Open'], 'r', wti_df['Date'], wti_df['Price'])
plt.subplot(222)
plt.plot(wti_df['Date'], wti_df['High'], 'r', wti_df['Date'], wti_df['Low'])
plt.subplot(223)'''
#### FIX THIS PLOT?
plt.plot(wti_df["Date"], wti_df["Change_PCT"].values)
plt.gcf().autofmt_xdate()

#plt.savefig('data/wti.png')
plt.show()
